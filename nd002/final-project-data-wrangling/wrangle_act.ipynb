# %% [markdown]
# # Wrangle and Analyze Data Project
#
# ## Introduction
#
#
# ## Rough notes/steps/thoughts
#
# - Wrangle dataset by gathering, assessing and cleaning the data
# - twitter file twitter_archive_enhanced.csv
# - download the image_predictions.tsv using requests (this was generated using a neural network)
# - WeRateDogs has a tweet id, use the twitter api (tweepy) and store the data in tweet_json.txt

# %%
import pandas as pd
import numpy as np
import requests
import tweepy
import json
import os
import re
import time
import csv
from datetime import datetime as dt

# %% [markdown]
# # Gathering Data

# %% [markdown]
# ### Twitter Archive Enhanced Dataset
# The twitter archive was downloaded from the course materials page. We can read it into pandas

# %%
twitter_archive = pd.read_csv('./twitter-archive-enhanced.csv')
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# ### Image Predictions Dataset
# We can download the `image_predictions.tsv` using the requests library, but we only want to download it once, if it exists we wont download it again

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
filename = 'image-predictions.tsv'

# if it doesn't exist, download the file using requests
if(not os.path.exists('.\{}'.format(filename))):
    # send a http get request to obtain the file at the above link
    image_prediction_file = requests.get(url)
    # write the file downloaded with requests 
    with open(filename,'wb') as ip_file:
        ip_file.write(image_prediction_file.content)

# %%
# open the file just to check it has been downloaded ok
image_predictions = pd.read_csv(filename, sep='\t')
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# ### Gathering Tweet information using the twitter api Tweepy
# We'll use the twitter API to obtain some extra information for each tweet

# %%
# this function takes in the API keys and returns the API object will be be used to obtain tweets
def get_twitter_api(consumer_key,consumer_secret, access_token, access_token_secret):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    return tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
# twitter api keys were saved as a JSON file, so when pushing to github I can use a .gitignore to ensure it doesn't get
# uploaded.
twitter_api = {}
twitter_api_filename = 'twitter_api_keys.json'
with open('./{}'.format(twitter_api_filename)) as twitter_api_keys:
    twitter_api = json.load(twitter_api_keys)

# %%
#api = get_twitter_api(CONSUMER_API_KEY, CONSUMER_SECRET,ACCESS_TOKEN,ACCESS_TOKEN_SECRET)
api = get_twitter_api(twitter_api['CONSUMER_API_KEY'], 
                      twitter_api['CONSUMER_SECRET'],
                      twitter_api['ACCESS_TOKEN'],
                      twitter_api['ACCESS_TOKEN_SECRET'])

# %% [markdown]
# ### Using The twitter API to pull Tweet Data (takes a long time)

# %%
tweet_json_filename = 'tweet_json.txt'

# %% [markdown]
# We want to obtain data for all tweet id's, there could be some tweet id's not in the `twitter_archive` dataframe but in the `image_predictions` file. I want to gather all unique Tweet IDs across both datasets

# %%
# 2356 unique tweet ids
tweet_ids_twitter_archive = twitter_archive['tweet_id'].unique()
# has 2075 unique
tweet_ids_image_predictions = image_predictions['tweet_id'].unique()

# %%
tweet_ids_twitter_archive.shape[0]
# Out:
# 2356

# %%
tweet_ids_image_predictions.shape[0]
# Out:
# 2075

# %% [markdown]
# We can find out how many tweet id's from `twitter_archive` are not in `image_predictions`

# %%
tid_in_archive_notin_prediction = [t_id for t_id in tweet_ids_twitter_archive if t_id not in tweet_ids_image_predictions]
len(tid_in_archive_notin_prediction)
# Out:
# 281

# %% [markdown]
# There are 281 missing from the `image_predictions` that we don't have data for. I also don't have the means to obtain this information as the data in the `image_predictions` dataset was generated using a neural network algorithm which was not provided nor is the scope if this assignment to write one.
#
# This also tells us that all tweet id's in the `image_predictions` dataframe are in the `twitter_archive` dataframe (as 281 + 2075 = 2356), hence tweet_ids in `image_predictions` are a subset of tweet_ids from `twitter_archive`. Therefore when using the twitter API to get tweet data, we can use the

# %%
# obtain all the twitter data

# if the file tweet_json.txt doesn't exist, then obtain the tweet
if (not os.path.exists('.\{}'.format(tweet_json_filename))):
    twitter_data = []
    errors = []
    
    # function will loop over all the tweet ids
    start_time = time.time()
    for index,tweet_id in enumerate(twitter_archive['tweet_id']):
        try:
            tweet_data = api.get_status(tweet_id, tweet_mode='extended')
            tweet_data_json = tweet_data._json

            # add the tweet_id into the json file, so we know which tweet it corresponds to, be careful here as the 
            # tweet is a large number, hence int64, which is not JSON serializable
            # "TypeError: Object of type 'int64' is not JSON serializable"
            # so convert to sting
            tweet_data_json['tweet_id'] = str(tweet_id)

            twitter_data.append(tweet_data_json)
        except Exception as e:
            print(e)
            errors.append({'index':index, 'tweet':tweet_id})
    end_time = time.time()

    # write the twitter data list to a txt file
    with open(tweet_json_filename, 'w') as json_tweet_file:
        for tweet in twitter_data:
            json.dump(tweet, json_tweet_file)
            #add a new line, so when we read we can read line by line
            json_tweet_file.write("\n")
        
    # write the errors, may want to return to those later
    with open('errors.txt','w') as error_file:
        # create the writer
        writer = csv.DictWriter(error_file, fieldnames=['index','tweet'])
        for error in errors:
            writer.writerow(error)

# %% [markdown]
# There are 6 tweet IDs that returned an exception, those have been recorded in `errors = []`

# %% [markdown]
# ### Read the extended tweet data back into a dataframe

# %%
# read the data back in from the txt file to check we can load it
extended_tweet_data = []
with open(tweet_json_filename,'r') as tweet_file:
    for line in tweet_file:
        tweet_json = json.loads(line)
        tweet_data = {
            'retweet_count':tweet_json['retweet_count'],
            'favorite_count':tweet_json['favorite_count'],
            'tweet_id':tweet_json['tweet_id']
            }
        extended_tweet_data.append(tweet_data)

# %%
# extract the elements from each tweet into a  dictionary, then build up a pandas dataframe
df_json_tweet = pd.DataFrame(extended_tweet_data, columns=['tweet_id', 'favorite_count','retweet_count'])
df_json_tweet.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           38884           8614
# 1  892177421306343426           33294           6328
# 2  891815181378084864           25090           4200
# 3  891689557279858688           42249           8726
# 4  891327558926688256           40396           9497

# %% [markdown]
# # Assess

# %% [markdown]
# Any observations have been added towards the end of this section, rather than under the

# %% [markdown]
# ### Visual Assessments

# %%
twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1951  673686845050527744                    NaN                  NaN
# 1171  720415127506415616                    NaN                  NaN
# 2191  668955713004314625                    NaN                  NaN
# 213   851591660324737024                    NaN                  NaN
# 871   761599872357261312                    NaN                  NaN
# 67    879376492567855104                    NaN                  NaN
# 2240  667924896115245057                    NaN                  NaN
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 1299  707738799544082433                    NaN                  NaN
# 1187  718460005985447936                    NaN                  NaN
#
#                       timestamp  \
# 1951  2015-12-07 02:13:55 +0000
# 1171  2016-04-14 00:55:25 +0000
# 2191  2015-11-24 00:54:05 +0000
# 213   2017-04-11 00:24:08 +0000
# 871   2016-08-05 16:28:54 +0000
# 67    2017-06-26 16:31:08 +0000
# 2240  2015-11-21 04:37:59 +0000
# 149   2017-05-12 17:12:53 +0000
# 1299  2016-03-10 01:24:13 +0000
# 1187  2016-04-08 15:26:28 +0000
#
#                                                  source  \
# 1951  <a href="http://twitter.com/download/iphone" r...
# 1171  <a href="http://twitter.com/download/iphone" r...
# 2191  <a href="http://twitter.com/download/iphone" r...
# 213   <a href="http://twitter.com/download/iphone" r...
# 871   <a href="http://twitter.com/download/iphone" r...
# 67    <a href="http://twitter.com/download/iphone" r...
# 2240  <a href="http://twitter.com/download/iphone" r...
# 149   <a href="http://twitter.com/download/iphone" r...
# 1299  <a href="http://vine.co" rel="nofollow">Vine -...
# 1187  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1951  This is George. He's upset that the 4th of Jul...                  NaN
# 1171  Garden's coming in nice this year. 10/10 https...                  NaN
# 2191  This is a Slovakian Helter Skelter Feta named ...                  NaN
# 213   Oh jeez u did me quite the spook little fella....                  NaN
# 871   This is Sephie. According to this picture, she...                  NaN
# 67    This is Jack AKA Stephen Furry. You're not sco...                  NaN
# 2240  This is Jiminy. He has always wanted to be a c...                  NaN
# 149   Ladies and gentlemen... I found Pipsy. He may ...                  NaN
# 1299  He's doing his best. 12/10 very impressive tha...                  NaN
# 1187  Meet Bowie. He's listening for underground squ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1951                       NaN                        NaN
# 1171                       NaN                        NaN
# 2191                       NaN                        NaN
# 213                        NaN                        NaN
# 871                        NaN                        NaN
# 67                         NaN                        NaN
# 2240                       NaN                        NaN
# 149                        NaN                        NaN
# 1299                       NaN                        NaN
# 1187                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1951  https://twitter.com/dog_rates/status/673686845...                11
# 1171  https://twitter.com/dog_rates/status/720415127...                10
# 2191  https://twitter.com/dog_rates/status/668955713...                10
# 213   https://twitter.com/dog_rates/status/851591660...                11
# 871   https://twitter.com/dog_rates/status/761599872...                11
# 67    https://twitter.com/dog_rates/status/879376492...                12
# 2240  https://twitter.com/dog_rates/status/667924896...                 9
# 149   https://twitter.com/dog_rates/status/863079547...                14
# 1299                      https://vine.co/v/hUvHKYrdb1d                12
# 1187  https://twitter.com/dog_rates/status/718460005...                 9
#
#       rating_denominator    name doggo floofer pupper puppo
# 1951                  10  George  None    None   None  None
# 1171                  10    None  None    None   None  None
# 2191                  10       a  None    None   None  None
# 213                   10    None  None    None   None  None
# 871                   10  Sephie  None    None   None  None
# 67                    10    Jack  None    None   None  None
# 2240                  10  Jiminy  None    None   None  None
# 149                   10    None  None    None   None  None
# 1299                  10    None  None    None   None  None
# 1187                  10   Bowie  None    None   None  None

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 401   824663926340194305                    NaN                  NaN
# 1022  746542875601690625                    NaN                  NaN
# 1151  725842289046749185                    NaN                  NaN
# 1596  686286779679375361                    NaN                  NaN
# 41    884441805382717440                    NaN                  NaN
# 667   790337589677002753                    NaN                  NaN
# 808   771770456517009408                    NaN                  NaN
# 39    884876753390489601                    NaN                  NaN
# 176   857746408056729600                    NaN                  NaN
# 811   771171053431250945                    NaN                  NaN
#
#                       timestamp  \
# 401   2017-01-26 17:02:56 +0000
# 1022  2016-06-25 03:17:46 +0000
# 1151  2016-04-29 00:21:01 +0000
# 1596  2016-01-10 20:41:33 +0000
# 41    2017-07-10 15:58:53 +0000
# 667   2016-10-23 23:42:19 +0000
# 808   2016-09-02 18:03:10 +0000
# 39    2017-07-11 20:47:12 +0000
# 176   2017-04-28 00:00:54 +0000
# 811   2016-09-01 02:21:21 +0000
#
#                                                  source  \
# 401   <a href="http://twitter.com/download/iphone" r...
# 1022  <a href="http://vine.co" rel="nofollow">Vine -...
# 1151  <a href="http://twitter.com/download/iphone" r...
# 1596  <a href="http://vine.co" rel="nofollow">Vine -...
# 41    <a href="http://twitter.com/download/iphone" r...
# 667   <a href="http://twitter.com/download/iphone" r...
# 808   <a href="http://twitter.com/download/iphone" r...
# 39    <a href="http://twitter.com/download/iphone" r...
# 176   <a href="http://twitter.com/download/iphone" r...
# 811   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 401   This is Wilson. Named after the volleyball. He...                  NaN
# 1022  Here's a golden floofer helping with the groce...                  NaN
# 1151  This is Colby. He's currently regretting all t...                  NaN
# 1596  When bae calls your name from across the room....                  NaN
# 41    I present to you, Pup in Hat. Pup in Hat is gr...                  NaN
# 667   Meet Maggie. She can hear your cells divide. 1...                  NaN
# 808   This is Davey. He'll have your daughter home b...                  NaN
# 39    This is Lola. It's her first time outside. Mus...                  NaN
# 176   Meet Thor. He doesn't have finals because he's...                  NaN
# 811   RT @dog_rates: This is Frankie. He's wearing b...         6.733201e+17
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 401                        NaN                        NaN
# 1022                       NaN                        NaN
# 1151                       NaN                        NaN
# 1596                       NaN                        NaN
# 41                         NaN                        NaN
# 667                        NaN                        NaN
# 808                        NaN                        NaN
# 39                         NaN                        NaN
# 176                        NaN                        NaN
# 811               4.196984e+09  2015-12-06 01:56:44 +0000
#
#                                           expanded_urls  rating_numerator  \
# 401   https://twitter.com/dog_rates/status/824663926...                13
# 1022                      https://vine.co/v/5uZYwqmuDeT                11
# 1151  https://twitter.com/dog_rates/status/725842289...                12
# 1596                      https://vine.co/v/iMZx6aDbExn                12
# 41    https://twitter.com/dog_rates/status/884441805...                14
# 667   https://twitter.com/dog_rates/status/790337589...                12
# 808   https://twitter.com/dog_rates/status/771770456...                11
# 39    https://twitter.com/dog_rates/status/884876753...                13
# 176   https://twitter.com/dog_rates/status/857746408...                13
# 811   https://twitter.com/dog_rates/status/673320132...                11
#
#       rating_denominator     name doggo  floofer pupper puppo
# 401                   10   Wilson  None     None   None  None
# 1022                  10     None  None  floofer   None  None
# 1151                  10    Colby  None     None   None  None
# 1596                  10     None  None     None   None  None
# 41                    10     None  None     None   None  None
# 667                   10   Maggie  None     None   None  None
# 808                   10    Davey  None     None   None  None
# 39                    10     Lola  None     None   None  None
# 176                   10     Thor  None     None   None  None
# 811                   10  Frankie  None     None   None  None

# %%
twitter_archive.shape
# Out:
# (2356, 17)

# %%
twitter_archive[twitter_archive.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# twitter_archive dataset has 2356 entries/rows, tweet ID is also referenced in image_predictions dataset, we can check if one table has more tweet_ids than the other.

# %%
image_predictions.shape
# Out:
# (2075, 12)

# %% [markdown]
# there are more tweet ids in twitter_archive than image_predictions, we can enter the missing tweets into a list

# %%
# will hold all the tweet id's that are missing from image_predictions that are in twitter_archive
missing_tweets_image_predictions = []

# twitter ids
tid_ta = list(twitter_archive['tweet_id'].unique())
tid_ip = list(image_predictions['tweet_id'].unique())

for tw_id in tid_ta:
    if tw_id not in tid_ip:
        missing_tweets_image_predictions.append(tw_id)

# %%
len(missing_tweets_image_predictions)
# Out:
# 281

# %% [markdown]
# There are 281 missing tweet ids from image_predictions

# %% [markdown]
# ## Assessment of Twitter Archive
#
# Quality (issues with content)
#
# - `in_reply_to_status_id`, `in_reply_to_user_id`, `retweeted_status_id`, `retweeted_status_user_id`, `retweeted_status_timestamp` all have NaN values
# - `expanded_urls` column is also incomplete, missing data
# - `timestamp` should be converted to time object
# - `retweeted_status_id` and `retweeted_status_user_id`, if they do have a tweet id, they are NaN (this is fine, as we need to remove the 181 retweets, we just want original data)
# - `in_reply_to_status_id` and `in_reply_to_user_id` also have the same issue
# - Some dogs do not have a dog stages assigned(pup, puppo, doggo etc)
# - Some dog stages have multiple types (eg puppo and doggo)
# - Some dog names look like they have been incorrectly extracted from the text. Some names are a, an or just.
#
# Tidiness
#
# - `source` column has the html tags, can remove the html tags and leave the inner text.
# - The dog stages are all in separate columns (doggo, pup), these can be melted into a single column

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
image_predictions[image_predictions.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
df_json_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# tweet_id          2345 non-null object
# favorite_count    2345 non-null int64
# retweet_count     2345 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 55.0+ KB

# %% [markdown]
# ## Assessment of Image Predictions
#
# - missing 281 tweets
#
# ## Assessment of JSON tweets
#
# - Tweet id is held as string object and needs to be int64 like the tweet id's from other tables

# %% [markdown]
# # Cleaning

# %%
# first take a copy of the datasets as we will be manipulaing them
twitter_archive_clean = twitter_archive.copy()

# %% [markdown]
# ## Delete Retweets, replies and unnecessary columns
#
# ### Delete Retweets
#
# #### Define
#
# - Remove the tweets that are retweets, leaving just original tweets using drop for rows that have a tweet id in the `retweeted_status_id`. We can also check the `retweeted_status_timestamp` or `retweeted_status_user_id` for entries, if they have a NaN then it is an original tweet
#
# #### Code

# %%
# retweeted_status_id can be removed as if it exists then it is a retweet, drop the rows
retweets = twitter_archive_clean[twitter_archive_clean['retweeted_status_id'].isnull()==False]
twitter_archive_clean.drop(retweets.index, inplace=True)
twitter_archive_clean.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### Test
#
# - To test the retweets have all been removed, we can check all the rows that have a value other than null/nan in the `retweeted_status_id` column.
# - We should also test the other columns that could indicate the row is a retweet such as `retweeted_status_user_id`,`retweeted_status_timestamp`, just incase `retweeted_status_id` was a null value and didn't have a tweet id

# %%
twitter_archive_clean[twitter_archive_clean['retweeted_status_id'].isnull()==False].shape[0]
# Out:
# 0

# %%
twitter_archive_clean[twitter_archive_clean['retweeted_status_user_id'].isnull()==False].shape[0]
# Out:
# 0

# %%
twitter_archive_clean[twitter_archive_clean['retweeted_status_timestamp'].isnull()==False].shape[0]
# Out:
# 0

# %%
twitter_archive_clean.shape[0]
# Out:
# 2175

# %% [markdown]
# All retweets have been removed, reducing the dataset to 2175 rows

# %% [markdown]
# ### Delete Replies
#
# #### Define
#
# - Remove tweets that are replies to tweets. We only want original tweets in this study. We can check for replies using the same method as we did for deleting retweets
#
# #### Code

# %%
# check for all rows which have an entry for in_reply_to_status_id or in_reply_to_user_id
twitter_archive_clean[twitter_archive_clean['in_reply_to_status_id'].isnull()==False]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 29    886267009285017600           8.862664e+17         2.281182e+09
# 52    881633300179243008           8.816070e+17         4.738443e+07
# 61    879674319642796034           8.795538e+17         3.105441e+09
# 101   870726314365509632           8.707262e+17         1.648776e+07
# 130   863427515083354112           8.634256e+17         7.759620e+07
# 131   863079547188785154           6.671522e+17         4.196984e+09
# 156   857214891891077121           8.571567e+17         1.806710e+08
# 159   856526610513747968           8.558181e+17         4.196984e+09
# 160   856288084350160898           8.562860e+17         2.792810e+08
# 162   855862651834028034           8.558616e+17         1.943518e+08
# 163   855860136149123072           8.558585e+17         1.361572e+07
# 187   850333567704068097           8.503288e+17         2.195506e+07
# 196   848213670039564288           8.482121e+17         4.196984e+09
# 200   847617282490613760           8.476062e+17         4.196984e+09
# 215   844979544864018432           7.590995e+17         4.196984e+09
# 234   840698636975636481           8.406983e+17         8.405479e+17
# 246   838150277551247360           8.381455e+17         2.195506e+07
# 247   838085839343206401           8.380855e+17         2.894131e+09
# 263   835246439529840640           8.352460e+17         2.625958e+07
# 287   832088576586297345           8.320875e+17         3.058208e+07
# 290   831926988323639298           8.319030e+17         2.068372e+07
# 326   826598799820865537           8.265984e+17         4.196984e+09
# 345   823333489516937216           8.233264e+17         1.582854e+09
# 358   821153421864615936           8.211526e+17         1.132119e+08
# 412   813130366689148928           8.131273e+17         4.196984e+09
# 426   811647686436880384           8.116272e+17         4.196984e+09
# 467   802265048156610565           7.331095e+17         4.196984e+09
# 470   801854953262350336           8.018543e+17         1.185634e+07
# 475   800859414831898624           8.008580e+17         2.918590e+08
# 492   797165961484890113           7.971238e+17         2.916630e+07
# ...                  ...                    ...                  ...
# 1300  693582294167244802           6.935722e+17         1.198989e+09
# 1318  692423280028966913           6.924173e+17         4.196984e+09
# 1322  692142790915014657           6.920419e+17         4.196984e+09
# 1344  690607260360429569           6.903413e+17         4.670367e+08
# 1419  686035780142297088           6.860340e+17         4.196984e+09
# 1426  685681090388975616           6.855479e+17         4.196984e+09
# 1439  684969860808454144           6.849598e+17         4.196984e+09
# 1451  684538444857667585           6.844811e+17         4.196984e+09
# 1455  684225744407494656           6.842229e+17         4.196984e+09
# 1484  682808988178739200           6.827884e+17         4.196984e+09
# 1510  681340665377193984           6.813394e+17         4.196984e+09
# 1595  678023323247357953           6.780211e+17         4.196984e+09
# 1640  676590572941893632           6.765883e+17         4.196984e+09
# 1663  675870721063669760           6.757073e+17         4.196984e+09
# 1665  675849018447167488           6.758457e+17         4.196984e+09
# 1673  675707330206547968           6.754971e+17         4.196984e+09
# 1687  675349384339542016           6.749998e+17         4.196984e+09
# 1703  674999807681908736           6.747934e+17         4.196984e+09
# 1706  674793399141146624           6.717299e+17         4.196984e+09
# 1713  674754018082705410           6.747522e+17         4.196984e+09
# 1716  674742531037511680           6.747400e+17         4.196984e+09
# 1726  674606911342424069           6.744689e+17         4.196984e+09
# 1735  674330906434379776           6.658147e+17         1.637468e+07
# 1761  673716320723169284           6.737159e+17         4.196984e+09
# 1857  671729906628341761           6.715610e+17         4.196984e+09
# 1859  671550332464455680           6.715449e+17         4.196984e+09
# 1970  669684865554620416           6.693544e+17         4.196984e+09
# 1990  669353438988365824           6.678065e+17         4.196984e+09
# 2010  668967877119254528           6.689207e+17         2.143566e+07
# 2117  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 29    2017-07-15 16:51:35 +0000
# 52    2017-07-02 21:58:53 +0000
# 61    2017-06-27 12:14:36 +0000
# 101   2017-06-02 19:38:25 +0000
# 130   2017-05-13 16:15:35 +0000
# 131   2017-05-12 17:12:53 +0000
# 156   2017-04-26 12:48:51 +0000
# 159   2017-04-24 15:13:52 +0000
# 160   2017-04-23 23:26:03 +0000
# 162   2017-04-22 19:15:32 +0000
# 163   2017-04-22 19:05:32 +0000
# 187   2017-04-07 13:04:55 +0000
# 196   2017-04-01 16:41:12 +0000
# 200   2017-03-31 01:11:22 +0000
# 215   2017-03-23 18:29:57 +0000
# 234   2017-03-11 22:59:09 +0000
# 246   2017-03-04 22:12:52 +0000
# 247   2017-03-04 17:56:49 +0000
# 263   2017-02-24 21:54:03 +0000
# 287   2017-02-16 04:45:50 +0000
# 290   2017-02-15 18:03:45 +0000
# 326   2017-02-01 01:11:25 +0000
# 345   2017-01-23 00:56:15 +0000
# 358   2017-01-17 00:33:26 +0000
# 412   2016-12-25 21:12:41 +0000
# 426   2016-12-21 19:01:02 +0000
# 467   2016-11-25 21:37:47 +0000
# 470   2016-11-24 18:28:13 +0000
# 475   2016-11-22 00:32:18 +0000
# 492   2016-11-11 19:55:50 +0000
# ...                         ...
# 1300  2016-01-30 23:51:19 +0000
# 1318  2016-01-27 19:05:49 +0000
# 1322  2016-01-27 00:31:15 +0000
# 1344  2016-01-22 18:49:36 +0000
# 1419  2016-01-10 04:04:10 +0000
# 1426  2016-01-09 04:34:45 +0000
# 1439  2016-01-07 05:28:35 +0000
# 1451  2016-01-06 00:54:18 +0000
# 1455  2016-01-05 04:11:44 +0000
# 1484  2016-01-01 06:22:03 +0000
# 1510  2015-12-28 05:07:27 +0000
# 1595  2015-12-19 01:25:31 +0000
# 1640  2015-12-15 02:32:17 +0000
# 1663  2015-12-13 02:51:51 +0000
# 1665  2015-12-13 01:25:37 +0000
# 1673  2015-12-12 16:02:36 +0000
# 1687  2015-12-11 16:20:15 +0000
# 1703  2015-12-10 17:11:09 +0000
# 1706  2015-12-10 03:30:58 +0000
# 1713  2015-12-10 00:54:28 +0000
# 1716  2015-12-10 00:08:50 +0000
# 1726  2015-12-09 15:09:55 +0000
# 1735  2015-12-08 20:53:11 +0000
# 1761  2015-12-07 04:11:02 +0000
# 1857  2015-12-01 16:37:44 +0000
# 1859  2015-12-01 04:44:10 +0000
# 1970  2015-11-26 01:11:28 +0000
# 1990  2015-11-25 03:14:30 +0000
# 2010  2015-11-24 01:42:25 +0000
# 2117  2015-11-18 20:02:51 +0000
#
#                                                  source  \
# 29    <a href="http://twitter.com/download/iphone" r...
# 52    <a href="http://twitter.com/download/iphone" r...
# 61    <a href="http://twitter.com/download/iphone" r...
# 101   <a href="http://twitter.com/download/iphone" r...
# 130   <a href="http://twitter.com/download/iphone" r...
# 131   <a href="http://twitter.com/download/iphone" r...
# 156   <a href="http://twitter.com/download/iphone" r...
# 159   <a href="http://twitter.com/download/iphone" r...
# 160   <a href="http://twitter.com/download/iphone" r...
# 162   <a href="http://twitter.com/download/iphone" r...
# 163   <a href="http://twitter.com/download/iphone" r...
# 187   <a href="http://twitter.com/download/iphone" r...
# 196   <a href="http://twitter.com/download/iphone" r...
# 200   <a href="http://twitter.com/download/iphone" r...
# 215   <a href="http://twitter.com/download/iphone" r...
# 234   <a href="http://twitter.com/download/iphone" r...
# 246   <a href="http://twitter.com/download/iphone" r...
# 247   <a href="http://twitter.com/download/iphone" r...
# 263   <a href="http://twitter.com/download/iphone" r...
# 287   <a href="http://twitter.com/download/iphone" r...
# 290   <a href="http://twitter.com/download/iphone" r...
# 326   <a href="http://twitter.com/download/iphone" r...
# 345   <a href="http://twitter.com/download/iphone" r...
# 358   <a href="http://twitter.com/download/iphone" r...
# 412   <a href="http://twitter.com/download/iphone" r...
# 426   <a href="http://twitter.com/download/iphone" r...
# 467   <a href="http://twitter.com/download/iphone" r...
# 470   <a href="http://twitter.com/download/iphone" r...
# 475   <a href="http://twitter.com/download/iphone" r...
# 492   <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 1300  <a href="http://twitter.com/download/iphone" r...
# 1318  <a href="http://twitter.com/download/iphone" r...
# 1322  <a href="http://twitter.com/download/iphone" r...
# 1344  <a href="http://twitter.com/download/iphone" r...
# 1419  <a href="http://twitter.com/download/iphone" r...
# 1426  <a href="http://twitter.com/download/iphone" r...
# 1439  <a href="http://twitter.com/download/iphone" r...
# 1451  <a href="http://twitter.com/download/iphone" r...
# 1455  <a href="http://twitter.com/download/iphone" r...
# 1484  <a href="http://twitter.com/download/iphone" r...
# 1510  <a href="http://twitter.com/download/iphone" r...
# 1595  <a href="http://twitter.com/download/iphone" r...
# 1640  <a href="http://twitter.com/download/iphone" r...
# 1663  <a href="http://twitter.com/download/iphone" r...
# 1665  <a href="http://twitter.com/download/iphone" r...
# 1673  <a href="http://twitter.com/download/iphone" r...
# 1687  <a href="http://twitter.com/download/iphone" r...
# 1703  <a href="http://twitter.com/download/iphone" r...
# 1706  <a href="http://twitter.com/download/iphone" r...
# 1713  <a href="http://twitter.com/download/iphone" r...
# 1716  <a href="http://twitter.com/download/iphone" r...
# 1726  <a href="http://twitter.com/download/iphone" r...
# 1735  <a href="http://twitter.com/download/iphone" r...
# 1761  <a href="http://twitter.com/download/iphone" r...
# 1857  <a href="http://twitter.com/download/iphone" r...
# 1859  <a href="http://twitter.com/download/iphone" r...
# 1970  <a href="http://twitter.com/download/iphone" r...
# 1990  <a href="http://twitter.com/download/iphone" r...
# 2010  <a href="http://twitter.com/download/iphone" r...
# 2117  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 29    @NonWhiteHat @MayhewMayhem omg hello tanner yo...                  NaN
# 52    @roushfenway These are good dogs but 17/10 is ...                  NaN
# 61                      @RealKentMurphy 14/10 confirmed                  NaN
# 101   @ComplicitOwl @ShopWeRateDogs &gt;10/10 is res...                  NaN
# 130   @Jack_Septic_Eye I'd need a few more pics to p...                  NaN
# 131   Ladies and gentlemen... I found Pipsy. He may ...                  NaN
# 156                        @Marc_IRL pixelated af 12/10                  NaN
# 159   THIS IS CHARLIE, MARK. HE DID JUST WANT TO SAY...                  NaN
# 160   @xianmcguire @Jenna_Marbles Kardashians wouldn...                  NaN
# 162   @dhmontgomery We also gave snoop dogg a 420/10...                  NaN
# 163   @s8n You tried very hard to portray this good ...                  NaN
# 187   @markhoppus MARK THAT DOG HAS SEEN AND EXPERIE...                  NaN
# 196   Jerry just apuppologized to me. He said there ...                  NaN
# 200   .@breaannanicolee PUPDATE: Cannon has a heart ...                  NaN
# 215   PUPDATE: I'm proud to announce that Toby is 23...                  NaN
# 234   @0_kelvin_0 &gt;10/10 is reserved for puppos s...                  NaN
# 246                                  @markhoppus 182/10                  NaN
# 247   @bragg6of8 @Andy_Pace_ we are still looking fo...                  NaN
# 263   @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
# 287            @docmisterio account started on 11/15/15                  NaN
# 290                              @UNC can confirm 12/10                  NaN
# 326   I was going to do 007/10, but the joke wasn't ...                  NaN
# 345                                @HistoryInPics 13/10                  NaN
# 358   @imgur for a polar bear tho I'd say 13/10 is a...                  NaN
# 412   I've been informed by multiple sources that th...                  NaN
# 426   PUPDATE: I've been informed that Augie was act...                  NaN
# 467   Like doggo, like pupper version 2. Both 11/10 ...                  NaN
# 470   .@NBCSports OMG THE TINY HAT I'M GOING TO HAVE...                  NaN
# 475   @SkyWilliams doggo simply protecting you from ...                  NaN
# 492   @JODYHiGHROLLER it may be an 11/10 but what do...                  NaN
# ...                                                 ...                  ...
# 1300  Personally I'd give him an 11/10. Not sure why...                  NaN
# 1318  PUPDATE: just noticed this dog has some extra ...                  NaN
# 1322  These are some pictures of Teddy that further ...                  NaN
# 1344                              12/10 @LightningHoltt                  NaN
# 1419  Yes I do realize a rating of 4/20 would've bee...                  NaN
# 1426  Jack deserves another round of applause. If yo...                  NaN
# 1439  For those who claim this is a goat, u are wron...                  NaN
# 1451  After watching this video, we've determined th...                  NaN
# 1455  Two sneaky puppers were not initially seen, mo...                  NaN
# 1484  I'm aware that I could've said 20/16, but here...                  NaN
# 1510  I've been told there's a slight possibility he...                  NaN
# 1595  After getting lost in Reese's eyes for several...                  NaN
# 1640  After some outrage from the crowd. Bubbles is ...                  NaN
# 1663  &amp; this is Yoshi. Another world record cont...                  NaN
# 1665  This dog is being demoted to a 9/10 for not we...                  NaN
# 1673  We've got ourselves a battle here. Watch out R...                  NaN
# 1687  Yea I lied. Here's more. All 13/10 https://t.c...                  NaN
# 1703  Ok last one of these. I may try to make some m...                  NaN
# 1706  I have found another. 13/10 https://t.co/HwroP...                  NaN
# 1713  Just received another perfect photo of dogs an...                  NaN
# 1716  Some clarification is required. The dog is sin...                  NaN
# 1726  The 13/10 also takes into account this impecca...                  NaN
# 1735                                       13/10\n@ABC7                  NaN
# 1761  The millennials have spoken and we've decided ...                  NaN
# 1857  I'm just going to leave this one here as well....                  NaN
# 1859  After 22 minutes of careful deliberation this ...                  NaN
# 1970  After countless hours of research and hundreds...                  NaN
# 1990  This is Tessa. She is also very pleased after ...                  NaN
# 2010                     12/10 good shit Bubka\n@wane15                  NaN
# 2117  After much debate this dog is being upgraded t...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 29                         NaN                        NaN
# 52                         NaN                        NaN
# 61                         NaN                        NaN
# 101                        NaN                        NaN
# 130                        NaN                        NaN
# 131                        NaN                        NaN
# 156                        NaN                        NaN
# 159                        NaN                        NaN
# 160                        NaN                        NaN
# 162                        NaN                        NaN
# 163                        NaN                        NaN
# 187                        NaN                        NaN
# 196                        NaN                        NaN
# 200                        NaN                        NaN
# 215                        NaN                        NaN
# 234                        NaN                        NaN
# 246                        NaN                        NaN
# 247                        NaN                        NaN
# 263                        NaN                        NaN
# 287                        NaN                        NaN
# 290                        NaN                        NaN
# 326                        NaN                        NaN
# 345                        NaN                        NaN
# 358                        NaN                        NaN
# 412                        NaN                        NaN
# 426                        NaN                        NaN
# 467                        NaN                        NaN
# 470                        NaN                        NaN
# 475                        NaN                        NaN
# 492                        NaN                        NaN
# ...                        ...                        ...
# 1300                       NaN                        NaN
# 1318                       NaN                        NaN
# 1322                       NaN                        NaN
# 1344                       NaN                        NaN
# 1419                       NaN                        NaN
# 1426                       NaN                        NaN
# 1439                       NaN                        NaN
# 1451                       NaN                        NaN
# 1455                       NaN                        NaN
# 1484                       NaN                        NaN
# 1510                       NaN                        NaN
# 1595                       NaN                        NaN
# 1640                       NaN                        NaN
# 1663                       NaN                        NaN
# 1665                       NaN                        NaN
# 1673                       NaN                        NaN
# 1687                       NaN                        NaN
# 1703                       NaN                        NaN
# 1706                       NaN                        NaN
# 1713                       NaN                        NaN
# 1716                       NaN                        NaN
# 1726                       NaN                        NaN
# 1735                       NaN                        NaN
# 1761                       NaN                        NaN
# 1857                       NaN                        NaN
# 1859                       NaN                        NaN
# 1970                       NaN                        NaN
# 1990                       NaN                        NaN
# 2010                       NaN                        NaN
# 2117                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 29                                                  NaN                12
# 52                                                  NaN                17
# 61                                                  NaN                14
# 101                                                 NaN                10
# 130                                                 NaN                12
# 131   https://twitter.com/dog_rates/status/863079547...                14
# 156                                                 NaN                12
# 159   https://twitter.com/dog_rates/status/856526610...                14
# 160                                                 NaN                14
# 162                                                 NaN               420
# 163                                                 NaN               666
# 187                                                 NaN                13
# 196                                                 NaN                11
# 200                                                 NaN                13
# 215   https://twitter.com/dog_rates/status/844979544...                13
# 234                                                 NaN                10
# 246                                                 NaN               182
# 247                                                 NaN                15
# 263                                                 NaN               960
# 287                                                 NaN                11
# 290                                                 NaN                12
# 326                                                 NaN                 7
# 345                                                 NaN                13
# 358                                                 NaN                13
# 412                                                 NaN                12
# 426                                                 NaN                11
# 467   https://twitter.com/dog_rates/status/802265048...                11
# 470                                                 NaN                11
# 475                                                 NaN                11
# 492                                                 NaN                11
# ...                                                 ...               ...
# 1300                                                NaN                11
# 1318                                                NaN                 9
# 1322  https://twitter.com/dog_rates/status/692142790...                13
# 1344                                                NaN                12
# 1419                                                NaN                 4
# 1426                                                NaN                14
# 1439                                                NaN                 5
# 1451  https://twitter.com/dog_rates/status/684538444...                12
# 1455  https://twitter.com/dog_rates/status/684225744...               143
# 1484                                                NaN                20
# 1510                                                NaN                 5
# 1595                                                NaN                13
# 1640                                                NaN                 7
# 1663  https://twitter.com/dog_rates/status/675870721...                11
# 1665                                                NaN                 9
# 1673  https://twitter.com/dog_rates/status/675707330...                11
# 1687  https://twitter.com/dog_rates/status/675349384...                13
# 1703  https://twitter.com/dog_rates/status/674999807...                13
# 1706  https://twitter.com/dog_rates/status/674793399...                13
# 1713  https://twitter.com/dog_rates/status/674754018...                12
# 1716                                                NaN                11
# 1726                                                NaN                13
# 1735                                                NaN                13
# 1761                                                NaN                 1
# 1857  https://twitter.com/dog_rates/status/671729906...                13
# 1859                                                NaN                 1
# 1970                                                NaN                11
# 1990  https://twitter.com/dog_rates/status/669353438...                10
# 2010                                                NaN                12
# 2117                                                NaN                10
#
#       rating_denominator   name  doggo floofer  pupper puppo
# 29                    10   None   None    None    None  None
# 52                    10   None   None    None    None  None
# 61                    10   None   None    None    None  None
# 101                   10   None   None    None    None  None
# 130                   10   None   None    None    None  None
# 131                   10   None   None    None    None  None
# 156                   10   None   None    None    None  None
# 159                   10   None   None    None    None  None
# 160                   10   None   None    None    None  None
# 162                   10   None   None    None    None  None
# 163                   10   None   None    None    None  None
# 187                   10   None   None    None    None  None
# 196                   10   None   None    None    None  None
# 200                   10   None   None    None    None  None
# 215                   10   None   None    None    None  None
# 234                   10   None   None    None    None  None
# 246                   10   None   None    None    None  None
# 247                   10   None   None    None    None  None
# 263                    0   None   None    None    None  None
# 287                   15   None   None    None    None  None
# 290                   10   None   None    None    None  None
# 326                   10   None   None    None    None  None
# 345                   10   None   None    None    None  None
# 358                   10   None   None    None    None  None
# 412                   10   None   None    None    None  None
# 426                   10   None   None    None    None  None
# 467                   10   None  doggo    None  pupper  None
# 470                   10   None   None    None    None  None
# 475                   10   None  doggo    None    None  None
# 492                   10   None   None    None    None  None
# ...                  ...    ...    ...     ...     ...   ...
# 1300                  10   None   None    None    None  None
# 1318                  10   None   None    None    None  None
# 1322                  10   None   None    None    None  None
# 1344                  10   None   None    None    None  None
# 1419                  20   None   None    None    None  None
# 1426                  10   None   None    None    None  None
# 1439                  10   None   None    None    None  None
# 1451                  10   None   None    None    None  None
# 1455                 130   None   None    None    None  None
# 1484                  16   None   None    None    None  None
# 1510                  10   None   None    None    None  None
# 1595                  10   None   None    None    None  None
# 1640                  10   None   None    None    None  None
# 1663                  10   None   None    None    None  None
# 1665                  10   None   None    None    None  None
# 1673                  10   None   None    None    None  None
# 1687                  10   None   None    None    None  None
# 1703                  10   None   None    None    None  None
# 1706                  10   None   None    None    None  None
# 1713                  10   None   None    None    None  None
# 1716                  10   None   None    None    None  None
# 1726                  10   None   None    None    None  None
# 1735                  10   None   None    None    None  None
# 1761                  10   None   None    None    None  None
# 1857                  10   None   None    None    None  None
# 1859                  10   None   None    None    None  None
# 1970                  10   None   None    None    None  None
# 1990                  10  Tessa   None    None    None  None
# 2010                  10   None   None    None    None  None
# 2117                  10   None   None    None    None  None
#
# [78 rows x 17 columns]

# %% [markdown]
# There are 78 rows in the dataset which are replies to a tweet

# %%
replies = twitter_archive_clean[twitter_archive_clean['in_reply_to_status_id'].isnull()==False]
twitter_archive_clean.drop(replies.index, inplace=True)
twitter_archive_clean.reset_index(inplace=True, drop=True)

# %% [markdown]
# #### Test
#
# - Test the replies have been removed by checking for non null values in both `in_reply_to_status_id` and `in_reply_to_user_id`

# %%
# check for all rows which have an entry for in_reply_to_status_id or in_reply_to_user_id
assert (twitter_archive_clean[twitter_archive_clean['in_reply_to_status_id'].isnull()==False].shape[0]==0 
        and 
        twitter_archive_clean[twitter_archive_clean['in_reply_to_user_id'].isnull()==False].shape[0]==0)

# %% [markdown]
# Assertion test passed

# %% [markdown]
# ### Delete columns no longer required
#
# #### Define
#
# No longer need the following columns
# - `in_reply_to_status_id`
# - `in_reply_to_user_id`
# - `retweeted_status_id`
# - `retweeted_status_user_id`
# - `retweeted_status_timestamp`
#
# #### Code

# %%
cols_to_drop = ['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp']
twitter_archive_clean.drop(labels=cols_to_drop, axis=1, inplace=True)
twitter_archive_clean.reset_index(inplace=True, drop=True)

# %% [markdown]
# #### Test
#
# - visual assesment will suffice, however i've also included an assertion as part of best practise

# %%
twitter_archive_clean.head(1)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None

# %%
# checks the length of the list for 0 (ok), which will be populated if columns that should have been deleted are present.
assert len([col for col in cols_to_drop if col in twitter_archive_clean.columns])==0

# %% [markdown]
# ## Convert Timestamp from string to datetime object

# %% [markdown]
# #### Define
#
# - The `timestamp` column is currently a string object, it needs to be converted to a datetime object. This can be done by using the datetimes string parse function `strptime()` which returns a datetime object
#
# #### Code

# %%
# function takes in the datetime string of the cell and returns the datetime object
def convert_to_datetime(dt_str):
    fmt = "%Y-%m-%d %H:%M:%S +0000"
    return dt.strptime(dt_str,fmt)

# %%
twitter_archive_clean['timestamp']= twitter_archive_clean['timestamp'].apply(convert_to_datetime)

# %% [markdown]
# #### Test
#
# - Visual test by checking the info, we should see thet `timestamp` column is a `datetime64[ns]` object

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097 entries, 0 to 2096
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 196.7+ KB

# %% [markdown]
# ## Cleaning source
#
# #### Define
#
# - The `source` column contains the full html tag a link, we don't need this as it contains the actual information as inner html text (the content of the tag). We will strip out the content of the tags
#
# #### Code

# %%
twitter_archive_clean['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     1964
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       31
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
# function that searches for the pattern group below, this extracts the text within an a html tag
def clean_source(html_tag):
    matches = re.search(r'>([\w\s\-]+)<', html_tag)
    if(matches!=None):
        return matches.group(1)
    else:
        return "no_url"
    
twitter_archive_clean['source']= twitter_archive_clean['source'].apply(clean_source)

# %%
# convert the source column to a categorical column
twitter_archive_clean['source'].astype('category')
twitter_archive_clean.head()
# Out:
#              tweet_id           timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
# 2  891815181378084864 2017-07-31 00:18:03  Twitter for iPhone
# 3  891689557279858688 2017-07-30 15:58:51  Twitter for iPhone
# 4  891327558926688256 2017-07-29 16:00:24  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# #### Test
#
# - I can check the value counts of the column

# %%
twitter_archive_clean['source'].value_counts()
# Out:
# Twitter for iPhone     1964
# Vine - Make a Scene      91
# Twitter Web Client       31
# TweetDeck                11
# Name: source, dtype: int64

# %% [markdown]
# ## Cleaning expanded_urls - delete column
#
# #### Define
#
# - expanded urls is not required, we can remove
#
# #### Code

# %%
twitter_archive_clean.drop('expanded_urls', axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
# test using visual - check columns
twitter_archive_clean.head(1)
# Out:
#              tweet_id           timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56  Twitter for iPhone
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None

# %%
assert 'expanded_urls' not in twitter_archive_clean.columns

# %% [markdown]
# ## Cleaning dog stages
#
# #### Define
#
# - It was noticed that some of the dogs have multiple stages, so a close look at this is important to see if we can determine the right dog stage
#
# #### Code

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
# just an option to change as we'll be looking at text and don't want it truncated in the view
pd.set_option('display.max_colwidth',-1)

# %% [markdown]
# The below code will take a look at the rows which have been assigned more than one dog stage

# %%
# function that checks the dataframe for rows with duplicate dog stages

def get_duplicate_dog_stages():
# extract just the dog stages
    dog_stages = twitter_archive_clean.loc[:,'doggo':'puppo']
    # assign a numeric value, 0=None and 1 if a dog_stage in the column, the sum in the row direction should not be more than 1
    dog_stages_numbers = dog_stages.applymap(lambda x: 1 if x !='None' else 0)

    # get counts (the number of dog stages)
    dog_stages_numbers['count'] = dog_stages_numbers.apply(sum, axis=1)
    # put all the bad indexes in a separate object
    bad_rows = dog_stages_numbers[dog_stages_numbers['count'] > 1]
    return bad_rows
bad_rows = get_duplicate_dog_stages()
bad_indexes = bad_rows.index

# %%
bad_rows
# Out:
#      doggo  floofer  pupper  puppo  count
# 154  1      0        0       1      2
# 161  1      1        0       0      2
# 358  1      0        1       0      2
# 416  1      0        1       0      2
# 446  1      0        1       0      2
# 536  1      0        1       0      2
# 562  1      0        1       0      2
# 689  1      0        1       0      2
# 748  1      0        1       0      2
# 848  1      0        1       0      2
# 897  1      0        1       0      2

# %%
twitter_archive_clean.iloc[bad_indexes,[3,7,8,9,10]]
# Out:
#                                                                                                                                                                      text  \
# 154  Here's a puppo participating in the #ScienceMarch. Cleverly disguising her own doggo agenda. 13/10 would keep the planet habitable for https://t.co/cMhq16isel
# 161  At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk
# 358  This is Dido. She's playing the lead role in "Pupper Stops to Catch Snow Before Resuming Shadow Box with Dried Apple." 13/10 (IG: didodoggo) https://t.co/m7isZrOBX7
# 416  Here we have Burke (pupper) and Dexter (doggo). Pupper wants to be exactly like doggo. Both 12/10 would pet at same time https://t.co/ANBpEYHaho
# 446  This is Bones. He's being haunted by another doggo of roughly the same size. 12/10 deep breaths pupper everything's fine https://t.co/55Dqe0SJNj
# 536  This is Pinot. He's a sophisticated doggo. You can tell by the hat. Also pointier than your average pupper. Still 10/10 would pet cautiously https://t.co/f2wmLZTPHd
# 562  Pupper butt 1, Doggo 0. Both 12/10 https://t.co/WQvcPEpH2u
# 689  Meet Maggie &amp; Lila. Maggie is the doggo, Lila is the pupper. They are sisters. Both 12/10 would pet at the same time https://t.co/MYwR4DQKll
# 748  Please stop sending it pictures that don't even have a doggo or pupper in them. Churlish af. 5/10 neat couch tho https://t.co/u2c9c7qSg8
# 848  This is just downright precious af. 12/10 for both pupper and doggo https://t.co/o5J479bZUC
# 897  Like father (doggo), like son (pupper). Both 12/10 https://t.co/pG2inLaOda
#
#      doggo  floofer  pupper  puppo
# 154  doggo  None     None    puppo
# 161  doggo  floofer  None    None
# 358  doggo  None     pupper  None
# 416  doggo  None     pupper  None
# 446  doggo  None     pupper  None
# 536  doggo  None     pupper  None
# 562  doggo  None     pupper  None
# 689  doggo  None     pupper  None
# 748  doggo  None     pupper  None
# 848  doggo  None     pupper  None
# 897  doggo  None     pupper  None

# %% [markdown]
# It looks like some of these lines would be difficult to programmatically determine what type of dog stage the dog is. Some of these are actually 2 dogs in the same picture.
#
# As there are only 11 rows I have decided to do manual analysis, here is what I will do
# - Delete tweets with multiple dogs in the same pic
# - if the tweet was about one dog type, correct the dog types in the main table
# - delete any that shouldn't have been sent in
#
# | Index | Text                                                                                                                                                                 | Decision                  | Notes                                         |
# |-------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------|-----------------------------------------------|
# | 154   | Here's a puppo participating in the #ScienceMarch. Cleverly disguising her own doggo agenda. 13/10 would keep the planet habitable for https://t.co/cMhq16isel       | puppo                     |                                               |
# | 161   | At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk | floofer                   |                                               |
# | 358   | This is Dido. She's playing the lead role in "Pupper Stops to Catch Snow Before Resuming Shadow Box with Dried Apple." 13/10 (IG: didodoggo) https://t.co/m7isZrOBX7 | pupper                    | doggo was found in the text with IG:didodoggo |
# | 416   | Here we have Burke (pupper) and Dexter (doggo). Pupper wants to be exactly like doggo. Both 12/10 would pet at same time https://t.co/ANBpEYHaho                     | 2 dogs                    | delete                                        |
# | 446   | This is Bones. He's being haunted by another doggo of roughly the same size. 12/10 deep breaths pupper everything's fine https://t.co/55Dqe0SJNj                     | pupper                    | tweet actually mentions the dog is a pupper   |
# | 536   | This is Pinot. He's a sophisticated doggo. You can tell by the hat. Also pointier than your average pupper. Still 10/10 would pet cautiously https://t.co/f2wmLZTPHd | doggo                     |                                               |
# | 562   | Pupper butt 1, Doggo 0. Both 12/10 https://t.co/WQvcPEpH2u                                                                                                           | 2 dogs                    | delete                                        |
# | 689   | Meet Maggie &amp; Lila. Maggie is the doggo, Lila is the pupper. They are sisters. Both 12/10 would pet at the same time https://t.co/MYwR4DQKll                     | 2 dogs                    | delete                                        |
# | 748   | Please stop sending it pictures that don't even have a doggo or pupper in them. Churlish af. 5/10 neat couch tho https://t.co/u2c9c7qSg8                             | should not have been sent | delete                                        |
# | 848   | This is just downright precious af. 12/10 for both pupper and doggo https://t.co/o5J479bZUC                                                                          | 2 dogs                    | delete                                        |
# | 897   | Like father (doggo), like son (pupper). Both 12/10 https://t.co/pG2inLaOda                                                                                           | 2 dogs                    | delete                                        |

# %%
# delete rows with index 416,562,689,748,848,897, Do not reset indexes until the cleaning operation has happened
delete_indexes = [416,562,689,748,848,897]
twitter_archive_clean.drop(delete_indexes, inplace=True)

# %%
# dictionary that holds what the new dog types will be
cleaned_dog_stages = {
    154 : 'puppo',
    161 : 'floofer',
    358 : 'pupper',
    446 : 'pupper',
    536 : 'doggo'
}

for k,v in cleaned_dog_stages.items():
    # reset the row to all None for all dog stages
    row = twitter_archive_clean.loc[k,'doggo':'puppo'].apply(lambda x: 'None')
    # change the dog stage to the value of the dog stage
    row[v]=v
    # write back into the dataframe
    twitter_archive_clean.loc[k,'doggo':'puppo'] = row

# %%
# now reset the index
twitter_archive_clean.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Test
#
# To test we can call the original code to ensure there are no rows with ambiguous or duplicate dog stages assigned

# %%
get_duplicate_dog_stages()
# Out:
# Empty DataFrame
# Columns: [doggo, floofer, pupper, puppo, count]
# Index: []

# %% [markdown]
# No rows with duplicates in

# %% [markdown]
# ## Melting/Collapsing dog stages
#
# #### Define
#
# - The dog stages information (doggo,floofer,pupper,puppo) all have their own column. We can collapse this information into a single column which is text for what the stage of dog is
#
#
# #### Code

# %%
# function to combine all the dog stages into a single result
def combine_dog_stages(row):
    dog_stage_list = list(row['doggo':'puppo'])
    # filter the list for None string
    dog_stage_result = list(filter(lambda x: x!='None', dog_stage_list))
    if (len(dog_stage_result)==0):
        return 'None'
    else:
        return dog_stage_result[0]

# Enter data into the dog stage
twitter_archive_clean['dog_stage']=twitter_archive_clean.apply(combine_dog_stages, axis=1)

# %% [markdown]
# #### Test
#
# We can test it worked by checking the value counts of the newly created column `dog_stage`

# %%
twitter_archive_clean['dog_stage'].value_counts()
# Out:
# None       1761
# pupper     223
# doggo      73
# puppo      24
# floofer    10
# Name: dog_stage, dtype: int64

# %% [markdown]
# We can also write a function to count the number of times the dog stage name appears in the old (wide format columns) and compare them against the counts we have in the new column

# %%
dog_stage_list_all = list(twitter_archive_clean['dog_stage'].value_counts().index)
# get rid of the None in the list
dog_stage_list = list(filter(lambda x:x!='None',dog_stage_list_all))

for dog_stage in dog_stage_list:
    assert twitter_archive_clean[dog_stage].value_counts()[dog_stage] == twitter_archive_clean['dog_stage'].value_counts()[dog_stage]

# %% [markdown]
# The test statement worked, we can now delete the old dog stage columns

# %%
dog_stage_list
# Out:
# ['pupper', 'doggo', 'puppo', 'floofer']

# %%
twitter_archive_clean.drop(dog_stage_list, axis=1, inplace=True)

# %% [markdown]
# # Image Predictions Cleaning

# %% [markdown]
# ## Get the highest dog prediction
#
# #### Define
#
# - The image predictions dataframe includes a number of predictions on what it has guessed and a level of confidence on the prediction. It also has a boolean value which determines if the guess is a dog or not a dog. To clean this dataset I will remove predictions that guessed the image was not a dog, and then only take the breed of the dog with the highest confidence

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0  1        Welsh_springer_spaniel  0.465074  True    collie
# 1  1        redbone                 0.506826  True    miniature_pinscher
# 2  1        German_shepherd         0.596461  True    malinois
# 3  1        Rhodesian_ridgeback     0.408143  True    redbone
# 4  1        miniature_pinscher      0.560311  True    Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665  True    Shetland_sheepdog    0.061428  True
# 1  0.074192  True    Rhodesian_ridgeback  0.072010  True
# 2  0.138584  True    bloodhound           0.116197  True
# 3  0.360687  True    miniature_pinscher   0.222752  True
# 4  0.243682  True    Doberman             0.154629  True

# %% [markdown]
# #### Code

# %%
p1_cols = ['tweet_id','p1','p1_conf','p1_dog']
p2_cols = ['tweet_id','p2','p2_conf','p2_dog']
p3_cols = ['tweet_id','p3','p3_conf','p3_dog']

p1_rename_dict = {'p1':'prediction','p1_conf':'confidence','p1_dog':'is_dog'}
p2_rename_dict = {'p2':'prediction','p2_conf':'confidence','p2_dog':'is_dog'}
p3_rename_dict = {'p3':'prediction','p3_conf':'confidence','p3_dog':'is_dog'}

p1_df = image_predictions.loc[:,p1_cols].rename(columns=p1_rename_dict)
p2_df = image_predictions.loc[:,p2_cols].rename(columns=p2_rename_dict)
p3_df = image_predictions.loc[:,p3_cols].rename(columns=p3_rename_dict)

stacked_image_predictions = pd.concat([p1_df,p2_df,p3_df], axis=0).copy()
stacked_image_predictions.reset_index(drop=True, inplace=True)
stacked_image_predictions.head(10)
# Out:
#              tweet_id              prediction  confidence  is_dog
# 0  666020888022790149  Welsh_springer_spaniel  0.465074    True
# 1  666029285002620928  redbone                 0.506826    True
# 2  666033412701032449  German_shepherd         0.596461    True
# 3  666044226329800704  Rhodesian_ridgeback     0.408143    True
# 4  666049248165822465  miniature_pinscher      0.560311    True
# 5  666050758794694657  Bernese_mountain_dog    0.651137    True
# 6  666051853826850816  box_turtle              0.933012    False
# 7  666055525042405380  chow                    0.692517    True
# 8  666057090499244032  shopping_cart           0.962465    False
# 9  666058600524156928  miniature_poodle        0.201493    True

# %%
# new stacked table should be 3 x size of the old
assert stacked_image_predictions.shape[0] == 3*image_predictions.shape[0]

# %%
# remove any predictions that are not a dog
tweet_not_dog = stacked_image_predictions[stacked_image_predictions['is_dog']==False].index
stacked_image_predictions.drop(tweet_not_dog, inplace=True)
stacked_image_predictions.reset_index(drop=True, inplace=True)
stacked_image_predictions.head(10)
# Out:
#              tweet_id              prediction  confidence  is_dog
# 0  666020888022790149  Welsh_springer_spaniel  0.465074    True
# 1  666029285002620928  redbone                 0.506826    True
# 2  666033412701032449  German_shepherd         0.596461    True
# 3  666044226329800704  Rhodesian_ridgeback     0.408143    True
# 4  666049248165822465  miniature_pinscher      0.560311    True
# 5  666050758794694657  Bernese_mountain_dog    0.651137    True
# 6  666055525042405380  chow                    0.692517    True
# 7  666058600524156928  miniature_poodle        0.201493    True
# 8  666063827256086533  golden_retriever        0.775930    True
# 9  666071193221509120  Gordon_setter           0.503672    True

# %%
# drop the is_dog column, as they're all true now
stacked_image_predictions.drop('is_dog', axis=1, inplace=True)
stacked_image_predictions.head()
# Out:
#              tweet_id              prediction  confidence
# 0  666020888022790149  Welsh_springer_spaniel  0.465074
# 1  666029285002620928  redbone                 0.506826
# 2  666033412701032449  German_shepherd         0.596461
# 3  666044226329800704  Rhodesian_ridgeback     0.408143
# 4  666049248165822465  miniature_pinscher      0.560311

# %% [markdown]
# Now we have lots of rows with the same tweet id, we want to group by the tweets and select the rows with the highest confidence

# %%
highest_confidence = stacked_image_predictions.groupby(['tweet_id'])['confidence'].max().reset_index()

# %%
# merge this with stacked_image_predictions table 
most_confident_predictions = pd.merge(left=highest_confidence, right=stacked_image_predictions, how='left',on=['tweet_id','confidence'])

# %% [markdown]
# #### Test

# %%
most_confident_predictions.head()
# Out:
#              tweet_id  confidence              prediction
# 0  666020888022790149  0.465074    Welsh_springer_spaniel
# 1  666029285002620928  0.506826    redbone
# 2  666033412701032449  0.596461    German_shepherd
# 3  666044226329800704  0.408143    Rhodesian_ridgeback
# 4  666049248165822465  0.560311    miniature_pinscher

# %% [markdown]
# ## Merging predictions with the twitter archive
#
# #### Define
#
# Need to merge all the separate tables into a single dataframe
#
# #### Code

# %%
# merge predictions and archive
merged_predictions_archive = pd.merge(left=twitter_archive_clean, right=most_confident_predictions, how='inner', on=['tweet_id']).copy()

# %% [markdown]
# #### Test
#
# This can be tested by looking at the dataframe

# %%
merged_predictions_archive.head(1)
# Out:
#              tweet_id           timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
#
#                                                                                                                                                                  text  \
# 0  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
#
#    rating_numerator  rating_denominator   name dog_stage  confidence  \
# 0  13                10                  Tilly  None      0.323581
#
#   prediction
# 0  Chihuahua

# %% [markdown]
# ## Merging json tweets with the twitter archive
#
# #### Define
#
# Final merge with JSON tweets and twitter archive,  first the JSON tweets tweet id needs to be converted to int64 then merged
#
# #### Code

# %%
df_json_tweet['tweet_id'] = df_json_tweet['tweet_id'].astype('int64')
df_json_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# tweet_id          2345 non-null int64
# favorite_count    2345 non-null int64
# retweet_count     2345 non-null int64
# dtypes: int64(3)
# memory usage: 55.0 KB

# %%
df_complete = pd.merge(left=merged_predictions_archive, right=df_json_tweet, how='inner', on=['tweet_id']).copy()

# %% [markdown]
# #### Test

# %%
df_complete.head(1)
# Out:
#              tweet_id           timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
#
#                                                                                                                                                                  text  \
# 0  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
#
#    rating_numerator  rating_denominator   name dog_stage  confidence  \
# 0  13                10                  Tilly  None      0.323581
#
#   prediction  favorite_count  retweet_count
# 0  Chihuahua  33294           6328

# %% [markdown]
# ## Cleaning dog stage
#
# #### Define
#
# Some of the dog stages (doggo, puppo etc) have None/Null for the value instead of a stage. In this section I will take a closer look by analysing the text. It may not be possible for all as some of the text may not actually give an indication on the dog stage, however I may be able to increase the number
#
# #### Code

# %%
df_complete['dog_stage'].value_counts()
# Out:
# None       1409
# pupper     168
# doggo      54
# puppo      22
# floofer    8
# Name: dog_stage, dtype: int64

# %% [markdown]
# 1409 dogs do not have a dog stage

# %%
# just get the rows that don't have a dog stage
no_dog_stage = df_complete.loc[:,['text','dog_stage']].query("dog_stage=='None'")
no_dog_stage.sample(10)
# Out:
#                                                                                                                                                                     text  \
# 1582  Meet Olive. He comes to spot by tree to reminisce of simpler times and truly admire his place in the universe. 11/10 https://t.co/LwrCwlWwPB
# 1566  This is Ron. Ron's currently experiencing a brain freeze. Damn it Ron. 8/10 https://t.co/4ilfcR5SlK
# 400   This is Daisy. She's here to make your day better. 13/10 mission h*ckin successful https://t.co/PbgvuD0qIL
# 881   This is Remington. He was caught off guard by the magical floating cheese. Spooked af. 10/10 deep breaths pup https://t.co/mhPSADiJmZ
# 110   This is Zooey. She's the world's biggest fan of illiterate delivery people. 13/10 not your fault they don't listen, Zooey https://t.co/ixOFQ1tfqE
# 1561  Here we have an Azerbaijani Buttermilk named Guss. He sees a demon baby Hitler behind his owner. 10/10 stays alert https://t.co/aeZykWwiJN
# 1028  Meet Tupawc. He's actually a Christian rapper. Doesn't even understand the concept of dollar signs. 10/10 great guy https://t.co/mCqgtqLDCW
# 1155  I know we joke around on here, but this is getting really frustrating. We rate dogs. Not T-Rex. Thank you... 8/10 https://t.co/5aFw7SWyxU
# 114   HI. MY. NAME. IS. BOOMER. AND. I. WANT. TO. SAY. IT'S. H*CKIN. RIDICULOUS. THAT. DOGS. CAN'T VOTE. ABSOLUTE. CODSWALLUP. THANK. YOU. 13/10 https://t.co/SqKJPwbQ2g
# 1571  Meet Otis. He is a Peruvian Quartzite. Pic sponsored by Planters. Ears on point. Killer sunglasses. 10/10 ily Otis https://t.co/tIaaBIMlJN
#
#      dog_stage
# 1582  None
# 1566  None
# 400   None
# 881   None
# 110   None
# 1561  None
# 1028  None
# 1155  None
# 114   None
# 1571  None

# %% [markdown]
# A lot of these have some variation of the dog stage name, eg I noticed floofapolis for the following

# %%
df_complete.iloc[790]['text']
# Out:
# "This is Neptune. He's a Snowy Swiss Mountain Floofapolis. Cheeky wink. Tongue nifty af. 11/10 would pet so firmly https://t.co/SoZq2Xoopv"

# %% [markdown]
# Some of the dog stages are also shortened such as *pup* or pluralised such as *puppers*. I will search for other variations of the dog stage words in all the text and see what matches.

# %%
from functools import reduce

dog_stage_variants = ['doggo','pup','floo']

# gets all the words found in the text but reduces the dictionary key value pairs to a single list with just words
def get_words(words_found_dictionary):
    # just get the items of the dictionary
    all_lists = list(words_found_dictionary.values())
    just_words = reduce(lambda x,y:x+y, all_lists)
    return just_words

def contains_dog_words(words_found_dictionary):
    list_of_dog_words_found = get_words(words_found_dictionary)
    if len(list_of_dog_words_found)==0:
        return False
    else:
        return True

# takes in the tweet text, returns a dictionary of all the words that came up 
def find_dog_stage_names(tweet_text):
    
    # variations of the dog stages, note that pup will find puppo and pupper, that's fine for now, we'll take a closer look later
    
    
    # construct and initalise a dictionary object from the possible dog stages in the list above
    dict_dog_stages = {ds:[] for ds in dog_stage_variants}
    
    # for each variation
    for dog_stage in dog_stage_variants:
        # match the words
        matches = re.finditer(dog_stage,tweet_text)
        
        # for each match
        for match in matches:
            # get the start position of the word in the tweet text, returns a tuple, so (start, end)
            start_pos = match.span()[0]
            
            # get the word that is referenced by the start position, take all the words
            # from the start position of the found word, split the sentence and take the
            # first word
            word_found = tweet_text[start_pos:].split(' ')[0]
            dict_dog_stages[dog_stage].append(word_found)
            
    return dict_dog_stages

# %%
# scan through all the rows/tweets which did not have a dog_stage assigned
text_results = []
for tweet_text in no_dog_stage['text']:
    # append the result in the dictionary
    text_results.append(find_dog_stage_names(tweet_text))

# %%
# how many in the list had a variation of the dog stage name
contains_words_list = list(map(lambda x:contains_dog_words(x), text_results))
all_false = [x for x in contains_words_list if x==False]
all_true = [x for x in contains_words_list if x==True]

message_results = "Out of {} tweets which did not have a dog stage assosicated, " +\
"{} were found to have some text in the tweet which could be used to determine the dog stage, " +\
"leaving {} that we cannot infer the stage of the dog"
print(message_results.format(no_dog_stage.shape[0], len(all_true), len(all_false)))
# Out:
# Out of 1409 tweets which did not have a dog stage assosicated, 213 were found to have some text in the tweet which could be used to determine the dog stage, leaving 1196 that we cannot infer the stage of the dog

# %% [markdown]
# def get_stage_names_for_tweet(row):
#     names = find_dog_stage_names(row['text'])
#     new_row = row
#     for ds in dog_stage_variants:
#         new_row[ds] = names[ds]
#     return new_row
# no_dog_stage.apply(get_stage_names_for_tweet, axis=1)

# %%
from pprint import PrettyPrinter
# reducer
pp = PrettyPrinter()

# This reducer will combine all the names for each key into a single list
reduce_dictionary = reduce(lambda x,y: {ds:x[ds]+y[ds] for ds in dog_stage_variants}, text_results)
# convert the dictionary items into a set, so we don't get repeats
for k,v in reduce_dictionary.items():
    reduce_dictionary[k] = set(v)


pp.pprint(reduce_dictionary)
# Out:
# {'doggo': {'doggos'},
#  'floo': {'floof',
#           'floof.',
#           'floofs',
#           'floofy',
#           'floor',
#           'floor.',
#           'flooring.'},
#  'pup': {'pup',
#          'pup!',
#          "pup's",
#          'pup,',
#          'pup.',
#          'puparazzi"',
#          'pupared',
#          'pupared.',
#          'pupholder.',
#          'pupkins',
#          'pupmost',
#          'pupnado.',
#          'puppa.',
#          'puppalled.',
#          'puppared',
#          'puppears',
#          'puppers',
#          'puppers.',
#          'puppertunity',
#          'pupplause',
#          'pupple',
#          'pupple.',
#          'puppoccino.',
#          'puppologize',
#          'pupporazzi.',
#          'pupporting',
#          'pupposes.',
#          'puppreciate',
#          'puppurchase',
#          'pupright',
#          'puprises',
#          'pups',
#          'pups.',
#          'pupset',
#          'pupset,',
#          'pupset.',
#          'pupsets',
#          'pupsicle.',
#          'pupside',
#          'puptacular',
#          'puptalk',
#          'puptection.',
#          'pupular.'}}

# %% [markdown]
# ### Summary of what was found in variations of the dog stages words
#
# __Doggo__
#
# All found doggos had the word doggos in the tweet text, we can convert these easily.
#
# __Floofer__
#
# There are more variants of the words for floofers, such as floof, floofs and floofy. Our algorithm also picked up the word floor, we can get ignore those.
#
# __Pupper__
#
# Pups is definitely the most difficult as i'm not sure of pups refers to puppo or puppers. I guess it would be puppos as it sounds like it's for a smaller animal but I will leave these out, I found someone else who shared my frustration https://imgur.com/gallery/EaWzw. The only ones I can be sure of for puppers are the following
#
# - puppa
# - puppers
#
# __summary__
#
# I will look for the following words and convert them
#
# - doggos
# - floof
# - floofs
# - floofy
# - puppa
# - puppers

# %%
words_to_match = ['doggos','floof','floofs','floofy','puppa','puppers']
def correct_dog_stages(row):
    if(row['dog_stage']=='None'):
        # try and find one of the words in the list above in the text
        for word_to_match in words_to_match:
            m = re.search(word_to_match, row['text'])
            if m!=None:
                # we have found a word
                found_word = m.group(0)
                start_letter = found_word[0]
                # if it starts with d it's doggo
                # if it starts with p it's a pupper
                # if it starts with f it's a floofer
                if start_letter=='d':
                    row['dog_stage']='doggo'
                elif start_letter=='p':
                    row['dog_stage']='pupper'
                elif start_letter=='f':
                    row['dog_stage']='floofer'
                else:
                    pass
    return row
    
df_complete_a = df_complete.apply(correct_dog_stages, axis=1)

# %% [markdown]
# #### Test
#
# How do we know it worked? we'll we couldn't fix all the dog stage names, there was a lot of uncertainly and to be sure I would have to look at the images myself or look at a machine learning algorithm. However we managed to find some, therefore we should see a reduction in the number of None/Null values from what was previously encountered. Originally we had 1409 tweets that did not have a dog stage. To test again we can query for `dog_stage=='None'` and do a count

# %%
df_complete_a[df_complete_a['dog_stage']=='None'].shape[0]
# Out:
# 1367

# %% [markdown]
# There are now only 1367 values which do not have a dog stage, so we managed to find 42 values during the cleaning process

# %% [markdown]
# ## Cleaning dog names

# %% [markdown]
# #### Define
#
# - Some of the dog names had None/Null values but some had a value such as a or an, this is due to the parser that detected sentences such as `this is {dog's name}` eg "this is rover" but would end up matching sentences such as "this is a {dog breed}". the a would be mistaken as the name.
#
# #### Code

# %%
df_complete_a['name'].value_counts()
# Out:
# None         397
# a            46
# Cooper       10
# Charlie      10
# Lucy         10
# Oliver       9
# Tucker       9
# Penny        8
# the          7
# Sadie        7
# Daisy        7
# Winston      7
# Toby         6
# Lola         6
# Jax          6
# Koda         6
# Stanley      5
# Rusty        5
# Leo          5
# Oscar        5
# Bo           5
# Bella        5
# Milo         4
# Bentley      4
# Dave         4
# Brody        4
# Bailey       4
# Jack         4
# Chester      4
# Scout        4
#             ..
# Acro         1
# Cal          1
# Kody         1
# Millie       1
# Ralpher      1
# Mac          1
# Klevin       1
# Nollie       1
# Ito          1
# Ralphie      1
# Bayley       1
# Layla        1
# Jeffri       1
# Blue         1
# Bert         1
# Duddles      1
# Comet        1
# Tango        1
# Scruffers    1
# Sprinkles    1
# Karll        1
# Gerbald      1
# Rizzy        1
# Clarkus      1
# space        1
# Frönq        1
# Hercules     1
# Iroh         1
# Horace       1
# Jameson      1
# Name: name, Length: 851, dtype: int64

# %%
df_complete_a['name'].value_counts().to_csv('names.csv')

# %% [markdown]
# - 397 names are `none`
# - 46 names are `a`
# - 7 names are `the`
# - 4 names are `an`
# - 2 names are `just`
# - 3 names are `very`
# - There are other names such as `unacceptable`, `O` and `all` but I have chosen to ignore those as they only appear once

# %%
# we can quickly glimps through some of the problems in csv, faster than in jupyter
# df_complete_a.query("name=='None' or name=='an' or name=='a' or name=='the' or name=='just'")['text'].to_csv('problem_names.csv')
missing_incorrect_names = df_complete_a.query("name=='None' or name=='an' or name=='a' or name=='the' or name=='just'")

# %%
# will pull names from a pattern
def extract_names(row):
    pattern_list=[
        r'named (\w+)',
        r'name is (\w+)'
    ]
    dog_breed = None
    dog_name = None
    for pattern in pattern_list:
        m = re.search(pattern, row['text'], re.IGNORECASE)
        if(m!=None):
            # row['dog_breed']=m.group(1)
            row['name']=m.group(1)
    return row.copy()

corrected_names = missing_incorrect_names.apply(extract_names, axis=1)

# %% [markdown]
# Some names have been found using this approach

# %%
incorrect_names = ['None','a','just','an']

# managed to find some names
names_found = [name for name in corrected_names['name'].unique().tolist() if name not in incorrect_names]
#corrected_names['name'].unique().tolist()
for name in names_found:
    print(name)
# Out:
# Zoey
# the
# Sabertooth
# Wylie
# Kip
# Jacob
# Rufus
# Spork
# Hemry
# Alfredo
# Zeus
# Leroi
# Berta
# Chuk
# Guss
# Alfonso
# Cheryl
# Jessiga
# Klint
# Big
# Tickles
# Kohl
# Daryl
# Octaviath
# Johm

# %%
# now to correct this in the main table
def fix_names(row):
    if(row['name'] in incorrect_names):
        return extract_names(row)
    else:
        return row
df_complete_b = df_complete_a.apply(fix_names, axis=1)

# %% [markdown]
# #### Test
#
# One way to check is compare the value counts of names with the previous value_counts `df_complete_a` vs `df_complete_b`

# %%
old_counts = df_complete_a['name'].value_counts().reset_index().rename(columns={'index':'name', 'name':'counts_old'})
new_counts = df_complete_b['name'].value_counts().reset_index().rename(columns={'index':'name', 'name':'counts_new'})

compare_counts = pd.merge(left=old_counts, right=new_counts, how='inner',on=['name'])
compare_counts['diff'] = compare_counts['counts_old'] - compare_counts['counts_new']
compare_counts[compare_counts['diff'] > 0]
# Out:
#     name  counts_old  counts_new  diff
# 0   None  397         391         6
# 1   a     46          29          17
# 45  an    4           3           1

# %% [markdown]
# We made the most difference to where `a` was placed by correcting a total of 17 rows

# %% [markdown]
# ## Cleaning incorrect submissions
#
# #### Define
#
# Some of the dog submissions were not correct. You can often see in the tweet message where the owner of WeRateDogs replies humourously asking users to stop sending pictures that aren't of dogs. We will look for sentences such as
#
# - please only send
# - we only rate dogs
# - not a dog
# - only send in dogs
# - guys
#
# We can also look for any submissions that had an unusual denominator
#
# #### Code

# %%
# some images aren't dogs
replies_to_bad_submission = ['please only send', 'we only rate dogs', 'not a dog', 'only send in dogs', 'guys']


def find_bad_submission(row):
    for bad_reply in replies_to_bad_submission:
        m = re.search(bad_reply, row['text'], re.IGNORECASE)
        if(m!=None):
            row['bad_reply']=True
        else:
            row['bad_reply']=False
        return row
bad_replies = df_complete_b.apply(find_bad_submission,axis=1).query("bad_reply==True")

# %% [markdown]
# #### Test

# %%
n_bad_replies = bad_replies.shape[0]
print("algorithm` has detected {} bad replies".format(n_bad_replies))
# Out:
# algorithm` has detected 16 bad replies

# %%
bad_replies
# Out:
#                 tweet_id           timestamp              source  \
# 22    887101392804085760 2017-07-18 00:07:08  Twitter for iPhone
# 38    883117836046086144 2017-07-07 00:17:54  Twitter for iPhone
# 71    874057562936811520 2017-06-12 00:15:36  Twitter for iPhone
# 133   855459453768019968 2017-04-21 16:33:22  Twitter for iPhone
# 166   845677943972139009 2017-03-25 16:45:08  Twitter for iPhone
# 350   809920764300447744 2016-12-17 00:38:52  Twitter for iPhone
# 474   781524693396357120 2016-09-29 16:03:01  Twitter for iPhone
# 667   746872823977771008 2016-06-26 01:08:52  Twitter for iPhone
# 671   746369468511756288 2016-06-24 15:48:42  Twitter for iPhone
# 708   739544079319588864 2016-06-05 19:47:03  Twitter for iPhone
# 815   715733265223708672 2016-04-01 02:51:22  Twitter for iPhone
# 1025  692919143163629568 2016-01-29 03:56:12  Twitter for iPhone
# 1111  685532292383666176 2016-01-08 18:43:29  Twitter for iPhone
# 1170  681297372102656000 2015-12-28 02:15:26  Twitter for iPhone
# 1235  677895101218201600 2015-12-18 16:56:01  Twitter for iPhone
# 1284  675878199931371520 2015-12-13 03:21:34  Twitter for iPhone
#
#                                                                                                                                                                     text  \
# 22    This... is a Jubilant Antarctic House Bear. We only rate dogs. Please only send dogs. Thank you... 12/10 would suffocate in floof https://t.co/4Ad1jzJSdp
# 38    Please only send dogs. We don't rate mechanics, no matter how h*ckin good. Thank you... 13/10 would sneak a pat https://t.co/Se5fZ9wp5E
# 71    I can't believe this keeps happening. This, is a birb taking a bath. We only rate dogs. Please only send dogs. Thank you... 12/10 https://t.co/pwY9PQhtP2
# 133   Guys, we only rate dogs. This is quite clearly a bulbasaur. Please only send dogs. Thank you... 12/10 human used pet, it's super effective https://t.co/Xc7uj1C64x
# 166   C'mon guys. Please only send in dogs. We only rate dogs, not Exceptional-Tongued Peruvian Floor Bears. Thank you... 12/10 https://t.co/z30iQLiXNo
# 350   Please only send in dogs. We only rate dogs, not seemingly heartbroken ewoks. Thank you... still 10/10 would console https://t.co/HIraYS1Bzo
# 474   Idk why this keeps happening. We only rate dogs. Not Bangladeshi Couch Chipmunks. Please only send dogs... 12/10 https://t.co/ya7bviQUUf
# 667   This is a carrot. We only rate dogs. Please only send in dogs. You all really should know this by now ...11/10 https://t.co/9e48aPrBm2
# 671   This is an Iraqi Speed Kangaroo. It is not a dog. Please only send in dogs. I'm very angry with all of you ...9/10 https://t.co/5qpBTTpgUt
# 708   This... is a Tyrannosaurus rex. We only rate dogs. Please only send in dogs. Thank you ...10/10 https://t.co/zxw8d5g94P
# 815   This is a taco. We only rate dogs. Please only send in dogs. Dogs are what we rate. Not tacos. Thank you... 10/10 https://t.co/cxl6xGY8B9
# 1025  Please only send in dogs. Don't submit other things like this pic of Kenny Chesney in a bathtub. Thank you. 9/10 https://t.co/TMpDHHGspy
# 1111  For the last time, WE. DO. NOT. RATE. BULBASAUR. We only rate dogs. Please only send dogs. Thank you ...9/10 https://t.co/GboDG8WhJG
# 1170  This is actually a lion. We only rate dogs. For the last time please only send dogs. Thank u.\n12/10 would still pet https://t.co/Pp26dMQxap
# 1235  Guys this was terrifying. Really spooked me up. We don't rate ghosts. We rate dogs. Please only send dogs... 9/10 https://t.co/EJImi1udYb
# 1284  Ok, I'll admit this is a pretty adorable bunny hopping towards the ocean but please only send in dogs... 11/10 https://t.co/sfsVCGIipI
#
#       rating_numerator  rating_denominator      name dog_stage  confidence  \
# 22    12                10                  None      floofer   0.733942
# 38    13                10                  None      None      0.949562
# 71    12                10                  None      None      0.832177
# 133   12                10                  quite     None      0.389513
# 166   12                10                  None      None      0.808681
# 350   10                10                  None      None      0.397163
# 474   12                10                  None      None      0.003523
# 667   11                10                  a         None      0.540201
# 671   9                 10                  an        None      0.622957
# 708   10                10                  None      None      0.967397
# 815   10                10                  a         None      0.740229
# 1025  9                 10                  None      None      0.612635
# 1111  9                 10                  None      None      0.095805
# 1170  12                10                  actually  None      0.482401
# 1235  9                 10                  None      None      0.550702
# 1284  11                10                  None      None      0.043627
#
#                     prediction  favorite_count  retweet_count  bad_reply
# 22    Samoyed                   30615           6018           True
# 38    golden_retriever          37304           6743           True
# 71    flat-coated_retriever     22758           4026           True
# 133   Blenheim_spaniel          31093           8745           True
# 166   chow                      26637           5218           True
# 350   Norwich_terrier           16922           4402           True
# 474   Chesapeake_Bay_retriever  22705           6235           True
# 667   Pembroke                  6448            2369           True
# 671   German_shepherd           6504            1814           True
# 708   Labrador_retriever        42708           23615          True
# 815   Dandie_Dinmont            4980            1856           True
# 1025  Saint_Bernard             2864            817            True
# 1111  collie                    3266            1270           True
# 1170  Lhasa                     3414            1057           True
# 1235  dalmatian                 5147            2322           True
# 1284  Cardigan                  4422            1529           True

# %% [markdown]
# The algorithm has worked, now we can remove these from the main table

# %%
df_complete_b.shape[0]
# Out:
# 1661

# %%
df_final = df_complete_b.drop(bad_replies.index)
df_final.reset_index(drop=True, inplace=True)
df_final.head()
# Out:
#              tweet_id           timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
# 1  891815181378084864 2017-07-31 00:18:03  Twitter for iPhone
# 2  891689557279858688 2017-07-30 15:58:51  Twitter for iPhone
# 3  891327558926688256 2017-07-29 16:00:24  Twitter for iPhone
# 4  891087950875897856 2017-07-29 00:08:17  Twitter for iPhone
#
#                                                                                                                                                                  text  \
# 0  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 1  This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 2  This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 3  This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
# 4  Here we have a majestic great white breaching off South Africa's coast. Absolutely h*ckin breathtaking. 13/10 (IG: tucker_marlo) #BarkWeek https://t.co/kQ04fDDRmh
#
#    rating_numerator  rating_denominator      name dog_stage  confidence  \
# 0  13                10                  Tilly     None      0.323581
# 1  12                10                  Archie    None      0.716012
# 2  13                10                  Darla     None      0.168086
# 3  12                10                  Franklin  None      0.555712
# 4  13                10                  None      None      0.425595
#
#                  prediction  favorite_count  retweet_count
# 0  Chihuahua                 33294           6328
# 1  Chihuahua                 25090           4200
# 2  Labrador_retriever        42249           8726
# 3  basset                    40396           9497
# 4  Chesapeake_Bay_retriever  20257           3142

# %%
df_final[df_final['rating_denominator']<10]
# Out:
#                 tweet_id           timestamp              source  \
# 340   810984652412424192 2016-12-19 23:06:23  Twitter for iPhone
# 1627  666287406224695296 2015-11-16 16:11:11  Twitter for iPhone
#
#                                                                                                                                                                            text  \
# 340   Meet Sam. She smiles 24/7 &amp; secretly aspires to be a reindeer. \nKeep Sam smiling by clicking and sharing this link:\nhttps://t.co/98tB8y7y7t https://t.co/LouL5vdvxx
# 1627  This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv
#
#       rating_numerator  rating_denominator name dog_stage  confidence  \
# 340   24                7                   Sam  None      0.871342
# 1627  1                 2                   an   None      0.857531
#
#             prediction  favorite_count  retweet_count
# 340   golden_retriever  5837            1612
# 1627  Maltese_dog       150             68

# %% [markdown]
# it looks like index tweet id `666287406224695296` is also an incorrect submission

# %%
episcopalian = df_final[df_final['tweet_id']==666287406224695296].index
df_final.drop(episcopalian, inplace=True)
df_final.reset_index(drop=True,inplace=True)

# %%
df_final.shape[0]
# Out:
# 1644

# %% [markdown]
# ## Write to csv
#
# #### Define
#
# This is so we can use it for visualisation, please note I have implemented the visualisation in another notebook named `wrangle_act_visualisation.ipynb`
#
# #### code

# %%
df_final.to_csv('twitter_archive_master.csv', encoding='utf-8')

# %% [markdown]
# # Visualisation in another file - `wrangle_act_visualisation.ipynb`
